# %%
import pandas as pd

# %%
#Save DataFrame to a CSV file
df.to_csv("people.csv", index=False)

# %%
df.to_excel("people.xlsx", index=False)

# %%
df.to_excel("people.xlsx", index=False, sheet_name="Sheet1")

# %%
df.to_json("people.json", orient="records")
#Produces a list of row objects (each row becomes a JSON object).

# %%
df.to_json("people.json", orient="records", indent=4)

# %% [markdown]
# # reading a csv file

# %%
s = pd.read_csv("D:\simple_data.csv")
s
# Out:
#    id name   age
# 0   1    A  25.0
# 1   2    B  25.0
# 2   3    C  28.0
# 3   4    D   NaN

# %%
s.values
# Out:
# array([[1, 'A', 25.0],
#        [2, 'B', 25.0],
#        [3, 'C', 28.0],
#        [4, 'D', nan]], dtype=object)

# %%
s.columns
# Out:
# Index(['id', 'name', 'age'], dtype='object')

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s['name']
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: name, dtype: object

# %% [markdown]
# # parameters of .read_csv

# %%
sep='\t',','
names=['c1','c2'] #Custom column names
index_col='c2' # which column you want to make index
header=1 # Row number used as header, or None header: 
#row number to use as the column headers (default is the first row);
use_cols=['c1','c2'] # colmn you want to include in your database 
nrows=100
na_values=(["NA", "Missing"])   #Additional strings to treat as NaN
skiprows              #Skip initial rows

# %%
pd.read_excel("file.xlsx", sheet_name="Sheet1")

# %%
pd.read_json("file.json")

# %% [markdown]
# #  from a web link (URL)

# %%
df = pd.read_csv("https://example.com/data.csv")

# %%
df = pd.read_csv("file.txt", sep="\t")

# %%
df=pd.read_csv("D:\samples_data.csv")
df
# Out:
#    id     name    age   gender     salary   join_date department  score
# 0   1    Alice   25.0        F    50000.0  2021-05-10      Sales   88.0
# 1   2      Bob   30.0        M    62000.0  2020/03/15         HR   92.0
# 2   3  Charlie    NaN        M    58000.0  15-07-2019         IT   79.0
# 3   4    david   45.0     male        NaN          IT        NaN    NaN
# 4   5      Eve   -3.0        F    72000.0  2022-13-01        NaN   65.0
# 5   5      Eve  200.0      NaN  1000000.0  2018-11-20    Finance  300.0
# 6   7    Frank   33.0        M    54000.0  wrong_date    finance   73.0
# 7   8      NaN   29.0   FEMALE    51000.0  2021-09-01      Sales   85.0
# 8   9   Grace     NaN        F    49000.0  2020/12/01      SALES   90.0
# 9  10    Henry   41.0  Unknown        NaN  2017-05-05         IT   82.0

# %%
pd.set_option("display.max_rows",300)
pd.set_option("display.max_columns",300)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.head(5)
# Out:
#    id     name   age gender   salary   join_date department  score
# 0   1    Alice  25.0      F  50000.0  2021-05-10      Sales   88.0
# 1   2      Bob  30.0      M  62000.0  2020/03/15         HR   92.0
# 2   3  Charlie   NaN      M  58000.0  15-07-2019         IT   79.0
# 3   4    david  45.0   male      NaN          IT        NaN    NaN
# 4   5      Eve  -3.0      F  72000.0  2022-13-01        NaN   65.0

# %%
df.columns
# Out:
# Index(['id', 'name', 'age', 'gender', 'salary', 'join_date', 'department',
#        'score'],
#       dtype='object')

# %% [markdown]
# # columns filtering

# %%
df[['id','name']]
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    david
# 4   5      Eve
# 5   5      Eve
# 6   7    Frank
# 7   8      NaN
# 8   9   Grace
# 9  10    Henry

# %%
df[['id', 'name', 'age', 'gender', 'salary', 'join_date']]
# Out:
#    id     name    age   gender     salary   join_date
# 0   1    Alice   25.0        F    50000.0  2021-05-10
# 1   2      Bob   30.0        M    62000.0  2020/03/15
# 2   3  Charlie    NaN        M    58000.0  15-07-2019
# 3   4    david   45.0     male        NaN          IT
# 4   5      Eve   -3.0        F    72000.0  2022-13-01
# 5   5      Eve  200.0      NaN  1000000.0  2018-11-20
# 6   7    Frank   33.0        M    54000.0  wrong_date
# 7   8      NaN   29.0   FEMALE    51000.0  2021-09-01
# 8   9   Grace     NaN        F    49000.0  2020/12/01
# 9  10    Henry   41.0  Unknown        NaN  2017-05-05

# %% [markdown]
# # dataframe attribute and methods

# %%
df.shape
# Out:
# (10, 8)

# %%
df.dtypes
# Out:
# id              int64
# name           object
# age           float64
# gender         object
# salary        float64
# join_date      object
# department     object
# score         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          10 non-null     int64
#  1   name        9 non-null      object
#  2   age         8 non-null      float64
#  3   gender      9 non-null      object
#  4   salary      8 non-null      float64
#  5   join_date   10 non-null     object
#  6   department  8 non-null      object
#  7   score       9 non-null      float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 772.0+ bytes

# %%
len(df.columns)
# Out:
# 8

# %%
df.values
# Out:
# array([[1, 'Alice', 25.0, 'F', 50000.0, '2021-05-10', 'Sales', 88.0],
#        [2, 'Bob', 30.0, 'M', 62000.0, '2020/03/15', 'HR', 92.0],
#        [3, 'Charlie', nan, 'M', 58000.0, '15-07-2019', 'IT', 79.0],
#        [4, 'david', 45.0, 'male', nan, 'IT', nan, nan],
#        [5, 'Eve', -3.0, 'F', 72000.0, '2022-13-01', nan, 65.0],
#        [5, 'Eve', 200.0, nan, 1000000.0, '2018-11-20', 'Finance', 300.0],
#        [7, 'Frank', 33.0, 'M', 54000.0, 'wrong_date', 'finance', 73.0],
#        [8, nan, 29.0, 'FEMALE', 51000.0, '2021-09-01', 'Sales', 85.0],
#        [9, ' Grace ', nan, 'F', 49000.0, '2020/12/01', 'SALES', 90.0],
#        [10, 'Henry', 41.0, 'Unknown', nan, '2017-05-05', 'IT', 82.0]],
#       dtype=object)

# %%
df.tail(5)
# Out:
#    id     name    age   gender     salary   join_date department  score
# 5   5      Eve  200.0      NaN  1000000.0  2018-11-20    Finance  300.0
# 6   7    Frank   33.0        M    54000.0  wrong_date    finance   73.0
# 7   8      NaN   29.0   FEMALE    51000.0  2021-09-01      Sales   85.0
# 8   9   Grace     NaN        F    49000.0  2020/12/01      SALES   90.0
# 9  10    Henry   41.0  Unknown        NaN  2017-05-05         IT   82.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          10 non-null     int64
#  1   name        9 non-null      object
#  2   age         8 non-null      float64
#  3   gender      9 non-null      object
#  4   salary      8 non-null      float64
#  5   join_date   9 non-null      object
#  6   department  9 non-null      object
#  7   score       9 non-null      float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 772.0+ bytes

# %%
This function produces descriptive statistics for the DataFrame, that is, the central tendency (mean, median, min, max, etc.), dispersion, etc. It analyses the data and generates an output for both numeric and non-numeric data types accordingly.

# %%
df.describe()
# Out:
#               id         age          salary       score
# count  10.000000    8.000000        8.000000    9.000000
# mean    5.400000   50.000000   174500.000000  106.000000
# std     3.025815   62.301112   333639.668762   73.252986
# min     1.000000   -3.000000    49000.000000   65.000000
# 25%     3.250000   28.000000    50750.000000   79.000000
# 50%     5.000000   31.500000    56000.000000   85.000000
# 75%     7.750000   42.000000    64500.000000   90.000000
# max    10.000000  200.000000  1000000.000000  300.000000

# %%
df.describe(include='all')
# Out:
#                id name         age gender          salary   join_date  \
# count   10.000000    9    8.000000      9        8.000000          10
# unique        NaN    8         NaN      5             NaN          10
# top           NaN  Eve         NaN      F             NaN  2021-05-10
# freq          NaN    2         NaN      3             NaN           1
# mean     5.400000  NaN   50.000000    NaN   174500.000000         NaN
# std      3.025815  NaN   62.301112    NaN   333639.668762         NaN
# min      1.000000  NaN   -3.000000    NaN    49000.000000         NaN
# 25%      3.250000  NaN   28.000000    NaN    50750.000000         NaN
# 50%      5.000000  NaN   31.500000    NaN    56000.000000         NaN
# 75%      7.750000  NaN   42.000000    NaN    64500.000000         NaN
# max     10.000000  NaN  200.000000    NaN  1000000.000000         NaN
#
#        department       score
# count           8    9.000000
# unique          6         NaN
# top         Sales         NaN
# ...

# %%
df.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9])
# Out:
#               id         age          salary       score
# count  10.000000    8.000000        8.000000    9.000000
# mean    5.400000   50.000000   174500.000000  106.000000
# std     3.025815   62.301112   333639.668762   73.252986
# min     1.000000   -3.000000    49000.000000   65.000000
# 10%     1.900000   16.600000    49700.000000   71.400000
# 25%     3.250000   28.000000    50750.000000   79.000000
# 50%     5.000000   31.500000    56000.000000   85.000000
# 75%     7.750000   42.000000    64500.000000   90.000000
# 90%     9.100000   91.500000   350400.000000  133.600000
# max    10.000000  200.000000  1000000.000000  300.000000

# %%
functions

# %%
value_count()
sort_value(ascending=False)
sort_index
set_index
rename
reset_index
unique
nunique
isnull
not null
has nan
dropna
fillna
drop_duplicates
drop
apply
isin

# %%
df['gender'].value_counts()
# Out:
# gender
# F          3
# M          3
# male       1
# FEMALE     1
# Unknown    1
# Name: count, dtype: int64

# %%
df['department'].value_counts()
# Out:
# department
# Sales      2
# IT         2
# HR         1
# Finance    1
# finance    1
# SALES      1
# Name: count, dtype: int64

# %%
df['gender'].unique()
# Out:
# array(['F', 'M', 'male', nan, 'FEMALE', 'Unknown'], dtype=object)

# %%
df['gender'].nunique()
# Out:
# 5

# %%
import numpy as np

# %%
df['gender']=df['gender'].map({'M':'male','F':'female','FEMALE':'female','male':'male','unknown':np.nan})

# %%
df['gender'].unique()
# Out:
# array(['female', 'male', nan], dtype=object)

# %%
df
# Out:
#    id     name    age  gender     salary   join_date department  score
# 0   1    Alice   25.0  female    50000.0  2021-05-10      Sales   88.0
# 1   2      Bob   30.0    male    62000.0  2020/03/15         HR   92.0
# 2   3  Charlie    NaN    male    58000.0  15-07-2019         IT   79.0
# 3   4    david   45.0    male        NaN          IT        NaN    NaN
# 4   5      Eve   -3.0  female    72000.0  2022-13-01        NaN   65.0
# 5   5      Eve  200.0     NaN  1000000.0  2018-11-20    Finance  300.0
# 6   7    Frank   33.0    male    54000.0  wrong_date    finance   73.0
# 7   8      NaN   29.0  female    51000.0  2021-09-01      Sales   85.0
# 8   9   Grace     NaN  female    49000.0  2020/12/01      SALES   90.0
# 9  10    Henry   41.0     NaN        NaN  2017-05-05         IT   82.0

# %%
df.shape
# Out:
# (10, 7)

# %%
df.set_index(['id'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10828\358591263.py in ?()
# ----> 1 df.set_index(['id'],inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['id'] are in the columns"

# %%
df.sort_values('score',ascending=False) # desc
# Out:
#        name    age  gender     salary   join_date department  score
# id
# 5       Eve  200.0     NaN  1000000.0  2018-11-20    Finance  300.0
# 2       Bob   30.0    male    62000.0  2020/03/15         HR   92.0
# 9    Grace     NaN  female    49000.0  2020/12/01      SALES   90.0
# 1     Alice   25.0  female    50000.0  2021-05-10      Sales   88.0
# 8       NaN   29.0  female    51000.0  2021-09-01      Sales   85.0
# 10    Henry   41.0     NaN        NaN  2017-05-05         IT   82.0
# 3   Charlie    NaN    male    58000.0  15-07-2019         IT   79.0
# 7     Frank   33.0    male    54000.0  wrong_date    finance   73.0
# 5       Eve   -3.0  female    72000.0  2022-13-01        NaN   65.0
# 4     david   45.0     NaN        NaN          IT        NaN    NaN

# %%
df.sort_values('score',ascending=False,na_position='first')
# Out:
#        name    age  gender     salary   join_date department  score
# id
# 4     david   45.0     NaN        NaN          IT        NaN    NaN
# 5       Eve  200.0     NaN  1000000.0  2018-11-20    Finance  300.0
# 2       Bob   30.0    male    62000.0  2020/03/15         HR   92.0
# 9    Grace     NaN  female    49000.0  2020/12/01      SALES   90.0
# 1     Alice   25.0  female    50000.0  2021-05-10      Sales   88.0
# 8       NaN   29.0  female    51000.0  2021-09-01      Sales   85.0
# 10    Henry   41.0     NaN        NaN  2017-05-05         IT   82.0
# 3   Charlie    NaN    male    58000.0  15-07-2019         IT   79.0
# 7     Frank   33.0    male    54000.0  wrong_date    finance   73.0
# 5       Eve   -3.0  female    72000.0  2022-13-01        NaN   65.0

# %%
df.sort_values(['salary','score'],ascending=[True,False])
# Out:
#    id     name    age  gender     salary   join_date department  score
# 8   9   Grace     NaN  female    49000.0  2020/12/01      SALES   90.0
# 0   1    Alice   25.0  female    50000.0  2021-05-10      Sales   88.0
# 7   8      NaN   29.0  female    51000.0  2021-09-01      Sales   85.0
# 6   7    Frank   33.0    male    54000.0  wrong_date    finance   73.0
# 2   3  Charlie    NaN    male    58000.0  15-07-2019         IT   79.0
# 1   2      Bob   30.0    male    62000.0  2020/03/15         HR   92.0
# 4   5      Eve   -3.0  female    72000.0  2022-13-01        NaN   65.0
# 5   5      Eve  200.0     NaN  1000000.0  2018-11-20    Finance  300.0
# 9  10    Henry   41.0     NaN        NaN  2017-05-05         IT   82.0
# 3   4    david   45.0     NaN        NaN          IT        NaN    NaN

# %%
df
# Out:
#        name    age  gender     salary   join_date department  score
# id
# 1     Alice   25.0  female    50000.0  2021-05-10      Sales   88.0
# 2       Bob   30.0    male    62000.0  2020/03/15         HR   92.0
# 3   Charlie    NaN    male    58000.0  15-07-2019         IT   79.0
# 4     david   45.0     NaN        NaN          IT        NaN    NaN
# 5       Eve   -3.0  female    72000.0  2022-13-01        NaN   65.0
# 5       Eve  200.0     NaN  1000000.0  2018-11-20    Finance  300.0
# 7     Frank   33.0    male    54000.0  wrong_date    finance   73.0
# 8       NaN   29.0  female    51000.0  2021-09-01      Sales   85.0
# 9    Grace     NaN  female    49000.0  2020/12/01      SALES   90.0
# 10    Henry   41.0     NaN        NaN  2017-05-05         IT   82.0

# %%
#This sorts the rows in ascending order of the index.
df.sort_index()
# Out:
#        name    age  gender     salary   join_date department  score
# id
# 1     Alice   25.0  female    50000.0  2021-05-10      Sales   88.0
# 2       Bob   30.0    male    62000.0  2020/03/15         HR   92.0
# 3   Charlie    NaN    male    58000.0  15-07-2019         IT   79.0
# 4     david   45.0     NaN        NaN          IT        NaN    NaN
# 5       Eve   -3.0  female    72000.0  2022-13-01        NaN   65.0
# 5       Eve  200.0     NaN  1000000.0  2018-11-20    Finance  300.0
# 7     Frank   33.0    male    54000.0  wrong_date    finance   73.0
# 8       NaN   29.0  female    51000.0  2021-09-01      Sales   85.0
# 9    Grace     NaN  female    49000.0  2020/12/01      SALES   90.0
# 10    Henry   41.0     NaN        NaN  2017-05-05         IT   82.0

# %%
df.sort_index(ascending=False)
# Out:
#        name    age  gender     salary   join_date department  score
# id
# 10    Henry   41.0     NaN        NaN  2017-05-05         IT   82.0
# 9    Grace     NaN  female    49000.0  2020/12/01      SALES   90.0
# 8       NaN   29.0  female    51000.0  2021-09-01      Sales   85.0
# 7     Frank   33.0    male    54000.0  wrong_date    finance   73.0
# 5       Eve   -3.0  female    72000.0  2022-13-01        NaN   65.0
# 5       Eve  200.0     NaN  1000000.0  2018-11-20    Finance  300.0
# 4     david   45.0     NaN        NaN          IT        NaN    NaN
# 3   Charlie    NaN    male    58000.0  15-07-2019         IT   79.0
# 2       Bob   30.0    male    62000.0  2020/03/15         HR   92.0
# 1     Alice   25.0  female    50000.0  2021-05-10      Sales   88.0

# %%
df.sort_index(axis=1) # sort by column name
# Out:
#       age department  gender   join_date     name     salary  score
# id
# 1    25.0      Sales  female  2021-05-10    Alice    50000.0   88.0
# 2    30.0         HR    male  2020/03/15      Bob    62000.0   92.0
# 3     NaN         IT    male  15-07-2019  Charlie    58000.0   79.0
# 4    45.0        NaN     NaN          IT    david        NaN    NaN
# 5    -3.0        NaN  female  2022-13-01      Eve    72000.0   65.0
# 5   200.0    Finance     NaN  2018-11-20      Eve  1000000.0  300.0
# 7    33.0    finance    male  wrong_date    Frank    54000.0   73.0
# 8    29.0      Sales  female  2021-09-01      NaN    51000.0   85.0
# 9     NaN      SALES  female  2020/12/01   Grace     49000.0   90.0
# 10   41.0         IT     NaN  2017-05-05    Henry        NaN   82.0

# %%
# Rename a single column

# %%
#df.rename(columns={"old_name": "new_name"}, inplace=True)
df.rename(columns={"name": "ename", "salary": "esalary"}, inplace=True)

# %%
df
# Out:
#    id     name    age   gender     salary   join_date department  score
# 0   1    Alice   25.0        F    50000.0  2021-05-10      Sales   88.0
# 1   2      Bob   30.0        M    62000.0  2020/03/15         HR   92.0
# 2   3  Charlie    NaN        M    58000.0  15-07-2019         IT   79.0
# 3   4    david   45.0     male        NaN          IT        NaN    NaN
# 4   5      Eve   -3.0        F    72000.0  2022-13-01        NaN   65.0
# 5   5      Eve  200.0      NaN  1000000.0  2018-11-20    Finance  300.0
# 6   7    Frank   33.0        M    54000.0  wrong_date    finance   73.0
# 7   8      NaN   29.0   FEMALE    51000.0  2021-09-01      Sales   85.0
# 8   9   Grace     NaN        F    49000.0  2020/12/01      SALES   90.0
# 9  10    Henry   41.0  Unknown        NaN  2017-05-05         IT   82.0

# %% [markdown]
# # null handling

# %%
df.isnull().sum()
# Out:
# id            0
# name          1
# age           2
# gender        0
# salary        2
# join_date     0
# department    2
# score         1
# dtype: int64

# %% [markdown]
# # drop nulls

# %%
	axis = 0 (by default) Drops rows
axis = 1 Drops columns

inplace = True    Modifies the original DataFrame
inplace = False (default)          Creates a new DataFrame

# %%
df
# Out:
#    id     name    age   gender     salary   join_date department  score
# 0   1    Alice   25.0        F    50000.0  2021-05-10      Sales   88.0
# 1   2      Bob   30.0        M    62000.0  2020/03/15         HR   92.0
# 2   3  Charlie    NaN        M    58000.0  15-07-2019         IT   79.0
# 3   4    david   45.0     male        NaN          IT        NaN    NaN
# 4   5      Eve   -3.0        F    72000.0  2022-13-01        NaN   65.0
# 5   5      Eve  200.0      NaN  1000000.0  2018-11-20    Finance  300.0
# 6   7    Frank   33.0        M    54000.0  wrong_date    finance   73.0
# 7   8      NaN   29.0   FEMALE    51000.0  2021-09-01      Sales   85.0
# 8   9   Grace     NaN        F    49000.0  2020/12/01      SALES   90.0
# 9  10    Henry   41.0  Unknown        NaN  2017-05-05         IT   82.0

# %%
df.dropna()  # delete all row having single null value
# Out:
#    id  ename   age  gender  esalary   join_date department  score
# 0   1  Alice  25.0  female  50000.0  2021-05-10      Sales   88.0
# 1   2    Bob  30.0    male  62000.0  2020/03/15         HR   92.0
# 6   7  Frank  33.0    male  54000.0  wrong_date    finance   73.0

# %%
df.dropna(how="all") #Drop rows only if ALL values are null
# Out:
#    id     name    age   gender     salary   join_date department  score
# 0   1    Alice   25.0        F    50000.0  2021-05-10      Sales   88.0
# 1   2      Bob   30.0        M    62000.0  2020/03/15         HR   92.0
# 2   3  Charlie    NaN        M    58000.0  15-07-2019         IT   79.0
# 3   4    david   45.0     male        NaN          IT        NaN    NaN
# 4   5      Eve   -3.0        F    72000.0  2022-13-01        NaN   65.0
# 5   5      Eve  200.0      NaN  1000000.0  2018-11-20    Finance  300.0
# 6   7    Frank   33.0        M    54000.0  wrong_date    finance   73.0
# 7   8      NaN   29.0   FEMALE    51000.0  2021-09-01      Sales   85.0
# 8   9   Grace     NaN        F    49000.0  2020/12/01      SALES   90.0
# 9  10    Henry   41.0  Unknown        NaN  2017-05-05         IT   82.0

# %%
df.dropna(subset=["age", "salary"],ignore_index=True)#Drop rows with nulls in specific columns
# Out:
#    id   name    age  gender     salary   join_date department  score
# 0   1  Alice   25.0       F    50000.0  2021-05-10      Sales   88.0
# 1   2    Bob   30.0       M    62000.0  2020/03/15         HR   92.0
# 2   5    Eve   -3.0       F    72000.0  2022-13-01        NaN   65.0
# 3   5    Eve  200.0     NaN  1000000.0  2018-11-20    Finance  300.0
# 4   7  Frank   33.0       M    54000.0  wrong_date    finance   73.0
# 5   8    NaN   29.0  FEMALE    51000.0  2021-09-01      Sales   85.0

# %% [markdown]
# # Drop rows or columns using a threshold

# %%
#Drop rows that have fewer than thresh non-null values

# drop row
df.dropna(axis=0, thresh=int(0.8*len(df)))    #inplace=True
#Keeps only row that have at least 80% non-null values
# threshold   means  minimum number of non-missing values required to KEEP the row.

# %%
df

df.dropna(axis=1, thresh=int(0.7*len(df))) #inplace=True
#Keeps only column that have at least 70% non-null values

# %% [markdown]
# # drop innecessary  column

# %%
df.drop('age', axis=1)
# Out:
#    id  ename  gender  esalary   join_date department  score
# 0   1  Alice  female  50000.0  2021-05-10      Sales   88.0
# 1   2    Bob    male  62000.0  2020/03/15         HR   92.0
# 6   7  Frank    male  54000.0  wrong_date    finance   73.0

# %%
#df = df.drop(['col1', 'col2'], axis=1)
# multiple column

# %%
del df['column_name']

# %%
df.pop('column_name')

# %% [markdown]
# # fillna

# %%
df.fillna("not_defined") # replace all null with "not defined"

# %%
df["age"].fillna(0)     # replace age null with 0

# %%
df["age"] = df["age"].fillna(df["age"].mean())

# %%
df["salary"] = df["salary"].fillna(df["salary"].median())

# %%
df["gender"].mode()
# Out:
# 0    F
# 1    M
# Name: gender, dtype: object

# %%
df["gender"] = df["gender"].fillna(df["gender"].mode()[0]) # return series 
#mode() calculates the most frequent value in the column

# %% [markdown]
# # outliers

# %%
import numpy as np
import pandas as pd

# %%
#IQR Method (Interquartile Range) — MOST COMMON
Outliers are values outside:

[ Q1 – 1.5*IQR ,  Q3 + 1.5*IQR ]

# %%
df = pd.DataFrame({
    'height': [150, 152, 153, 151, 149, 155, 300, 148, 152, 154],
    'weight': [50, 52, 53, 49, 51, 55, 200, 48, 52, 54]
})
df
# Out:
#    height  weight
# 0     150      50
# 1     152      52
# 2     153      53
# 3     151      49
# 4     149      51
# 5     155      55
# 6     300     200
# 7     148      48
# 8     152      52
# 9     154      54

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,2))
plt.boxplot(df['height'], vert=False)
plt.title("Height Boxplot")
plt.grid(True)
plt.show()

# %%
Five-Number Summary
Minimum (not counting outliers)
Q1 (25th percentile)
Median (50th percentile)
Q3 (75th percentile)
Maximum (not counting outliers)

# %%
Q1 = df['height'].quantile(0.25)
Q3 = df['height'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['height'] < lower) | (df['height'] > upper)]

# %%
print(upper)
print(lower)
# Out:
# 159.0
# 145.0

# %%
outliers
# Out:
#    height  weight
# 6     300     200

# %%
#Using np.where() to mark outliers
df['is_outlier'] = np.where(
    (df['height'] < lower) | (df['height'] > upper),
    'Yes', 'No'
)

# %%
df
# Out:
#    height  weight is_outlier
# 0     150      50         No
# 1     152      52         No
# 2     153      53         No
# 3     151      49         No
# 4     149      51         No
# 5     155      55         No
# 6     300     200        Yes
# 7     148      48         No
# 8     152      52         No
# 9     154      54         No

# %%
# Trimming means removing outliers completely from the dataset — not replacing them.
#trimming deletes the entire row containing the outlier.
new_df = df[(df['height'] > lower) & (df['height'] < upper)]

# %%
new_df
# Out:
#    height  weight is_outlier
# 0     150      50         No
# 1     152      52         No
# 2     153      53         No
# 3     151      49         No
# 4     149      51         No
# 5     155      55         No
# 7     148      48         No
# 8     152      52         No
# 9     154      54         No

# %%
# Capping = replacing outliers with limits
df['height']=np.where(df['height']>upper,upper,np.where(df['height']<lower,lower,df['height']))
print(df)
# Out:
#    height  weight
# 0   150.0      50
# 1   152.0      52
# 2   153.0      53
# 3   151.0      49
# 4   149.0      51
# 5   155.0      55
# 6   159.0     200
# 7   148.0      48
# 8   152.0      52
# 9   154.0      54

# %%
df['height'] = df['height'].clip(lower=lower, upper=upper)

#If a value is less than lower, it becomes lower
#If a value is greater than upper, it becomes upper
#Values within the range remain unchanged

# %% [markdown]
# # drop duplicates

# %% [markdown]
# # Detect Duplicates

# %%
#Check which rows are duplicates
df.duplicated()
#Returns a Boolean Series (True if the row is a duplicate, False otherwise).
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data={'id':2,'name':'Bob','age':30.0,'gender':'M','salary':62000.0,'join_date':'2020/03/15','department':'HR','score':92.0}
df1=pd.DataFrame([data])
df=pd.concat([df,df1],ignore_index=True)

# %%
df

# %%
df2=df[df.duplicated(subset=['id'],keep=False)]

# %%
df2

# %%
df[~df.duplicated(subset=["id"])]

# %%
df.drop_duplicates(inplace=True,keep="first")

# %%
df.drop_duplicates(subset=["id"], inplace=True)

# %%
df.drop_duplicates(subset=["id"], keep="last", inplace=True)

# %%
df.drop_duplicates(subset=["id"], keep=False, inplace=True)

# %%
# Count duplicates

df.duplicated().sum()          # Count duplicates in all columns

# %%
df
# Out:
#    id     name    age   gender     salary   join_date department  score
# 0   1    Alice   25.0        F    50000.0  2021-05-10      Sales   88.0
# 1   2      Bob   30.0        M    62000.0  2020/03/15         HR   92.0
# 2   3  Charlie    NaN        M    58000.0  15-07-2019         IT   79.0
# 3   4    david   45.0     male        NaN          IT        NaN    NaN
# 4   5      Eve   -3.0        F    72000.0  2022-13-01        NaN   65.0
# 5   5      Eve  200.0      NaN  1000000.0  2018-11-20    Finance  300.0
# 6   7    Frank   33.0        M    54000.0  wrong_date    finance   73.0
# 7   8      NaN   29.0   FEMALE    51000.0  2021-09-01      Sales   85.0
# 8   9   Grace     NaN        F    49000.0  2020/12/01      SALES   90.0
# 9  10    Henry   41.0  Unknown        NaN  2017-05-05         IT   82.0

# %%
#Check duplicates in a specific column
df.duplicated(subset=["id"])   # second occurance row
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %% [markdown]
# # drop duplicates

# %%
#Drop duplicate rows based on all columns
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#    id  ename   age  gender  esalary   join_date department  score
# 0   1  Alice  25.0  female  50000.0  2021-05-10      Sales   88.0
# 1   2    Bob  30.0    male  62000.0  2020/03/15         HR   92.0
# 6   7  Frank  33.0    male  54000.0  wrong_date    finance   73.0

# %%
#Drop duplicates row  based on specific columns
df.drop_duplicates(subset=["id"], inplace=True)
#Keeps the first occurrence by default.

# %%
df
# Out:
#    id     name   age   gender   salary   join_date department  score
# 0   1    Alice  25.0        F  50000.0  2021-05-10      Sales   88.0
# 1   2      Bob  30.0        M  62000.0  2020/03/15         HR   92.0
# 2   3  Charlie   NaN        M  58000.0  15-07-2019         IT   79.0
# 3   4    david  45.0     male      NaN          IT        NaN    NaN
# 4   5      Eve  -3.0        F  72000.0  2022-13-01        NaN   65.0
# 6   7    Frank  33.0        M  54000.0  wrong_date    finance   73.0
# 7   8      NaN  29.0   FEMALE  51000.0  2021-09-01      Sales   85.0
# 8   9   Grace    NaN        F  49000.0  2020/12/01      SALES   90.0
# 9  10    Henry  41.0  Unknown      NaN  2017-05-05         IT   82.0

# %%
#Keep last occurrence instead of first
df.drop_duplicates(subset=["id"], keep="last", inplace=True)

# %%
#Drop all duplicates (keep none)
df.drop_duplicates(subset=["id"], keep=False, inplace=True)
#Removes all rows that have duplicates in the subset.

# %%
# Count duplicates

df.duplicated().sum()          # Count duplicates in all columns
# Out:
# np.int64(0)

# %% [markdown]
# # Flag duplicates based on id (most common)

# %%
df["is_duplicate_id"] = df.duplicated(subset=["id"], keep=False)
# Mark all occurrences of a duplicate as True

# %%
df
# Out:
#    id     name   age   gender   salary   join_date department  score  \
# 0   1    Alice  25.0        F  50000.0  2021-05-10      Sales   88.0
# 1   2      Bob  30.0        M  62000.0  2020/03/15         HR   92.0
# 2   3  Charlie   NaN        M  58000.0  15-07-2019         IT   79.0
# 3   4    david  45.0     male      NaN          IT        NaN    NaN
# 4   5      Eve  -3.0        F  72000.0  2022-13-01        NaN   65.0
# 6   7    Frank  33.0        M  54000.0  wrong_date    finance   73.0
# 7   8      NaN  29.0   FEMALE  51000.0  2021-09-01      Sales   85.0
# 8   9   Grace    NaN        F  49000.0  2020/12/01      SALES   90.0
# 9  10    Henry  41.0  Unknown      NaN  2017-05-05         IT   82.0
#
#    is_duplicate_id
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# 6            False
# 7            False
# 8            False
# 9            False

# %%
df["is_duplicate_name"] = df.duplicated(subset=["name"], keep=False)

# %%
df["is_duplicate_combo"] = df.duplicated(
    subset=["name", "age", "department"], 
    keep=False
)

# %%
#Extract only duplicate rows
duplicate_rows = df[df["is_duplicate_id"]]

# %%
# Count duplicates
df["id"].value_counts()[df["id"].value_counts() > 1]

# %% [markdown]
# # rename column

# %%
#Rename a single column
df.rename(columns={"old_name": "new_name"}, inplace=True)
df.rename(columns={"age": "Age", "salary": "Salary_USD"}, inplace=True)

# %%
#Rename all columns at once
df.columns = ["ID", "Name", "Age", "Gender", "Salary", "JoinDate", "Department", "Score"]

# %% [markdown]
# # Drop Columns

# %%
#Drop a  unnecessary single column
df.drop("column_name", axis=1, inplace=True)

# %%
#Drop multiple columns
df.drop(["score", "join_date"], axis=1, inplace=True)

# %% [markdown]
# # filter the data based on condition

# %%
df[df["department"].isin(["Sales", "IT"])]
# Out:
#    id     name   age   gender   salary   join_date department  score  \
# 0   1    Alice  25.0        F  50000.0  2021-05-10      Sales   88.0
# 2   3  Charlie   NaN        M  58000.0  15-07-2019         IT   79.0
# 7   8      NaN  29.0   FEMALE  51000.0  2021-09-01      Sales   85.0
# 9  10    Henry  41.0  Unknown      NaN  2017-05-05         IT   82.0
#
#    is_duplicate_id
# 0            False
# 2            False
# 7            False
# 9            False

# %%
df[df["department"].isin(["Sales", "it"])]

# %%
df[~df["salary"].isna()]
# Out:
#    id     name   age  gender   salary   join_date department  score  \
# 0   1    Alice  25.0       F  50000.0  2021-05-10      Sales   88.0
# 1   2      Bob  30.0       M  62000.0  2020/03/15         HR   92.0
# 2   3  Charlie   NaN       M  58000.0  15-07-2019         IT   79.0
# 4   5      Eve  -3.0       F  72000.0  2022-13-01        NaN   65.0
# 6   7    Frank  33.0       M  54000.0  wrong_date    finance   73.0
# 7   8      NaN  29.0  FEMALE  51000.0  2021-09-01      Sales   85.0
# 8   9   Grace    NaN       F  49000.0  2020/12/01      SALES   90.0
#
#    is_duplicate_id
# 0            False
# 1            False
# 2            False
# 4            False
# 6            False
# 7            False
# 8            False

# %%
#Find rows with missing values using isna()
df[df["salary"].isna()]

# %%
#Find all rows where department is Sales (case-insensitive)
df["department"].str.lower().isin(["sales",'it'])

# %%
df[df["department"].str.lower().isin(["sales"])]

# %% [markdown]
# # acess the row

# %%
df
# Out:
#    id     name   age   gender   salary   join_date department  score  \
# 0   1    Alice  25.0        F  50000.0  2021-05-10      Sales   88.0
# 1   2      Bob  30.0        M  62000.0  2020/03/15         HR   92.0
# 2   3  Charlie   NaN        M  58000.0  15-07-2019         IT   79.0
# 3   4    david  45.0     male      NaN          IT        NaN    NaN
# 4   5      Eve  -3.0        F  72000.0  2022-13-01        NaN   65.0
# 6   7    Frank  33.0        M  54000.0  wrong_date    finance   73.0
# 7   8      NaN  29.0   FEMALE  51000.0  2021-09-01      Sales   85.0
# 8   9   Grace    NaN        F  49000.0  2020/12/01      SALES   90.0
# 9  10    Henry  41.0  Unknown      NaN  2017-05-05         IT   82.0
#
#    is_duplicate_id
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# 6            False
# 7            False
# 8            False
# 9            False

# %%
df['id']
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5
# 6     7
# 7     8
# 8     9
# 9    10
# Name: id, dtype: int64

# %%
df[['id']]
# Out:
#    id
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
# 6   7
# 7   8
# 8   9
# 9  10

# %%
df[['id','name','age']]
# Out:
#    id     name   age
# 0   1    Alice  25.0
# 1   2      Bob  30.0
# 2   3  Charlie   NaN
# 3   4    david  45.0
# 4   5      Eve  -3.0
# 6   7    Frank  33.0
# 7   8      NaN  29.0
# 8   9   Grace    NaN
# 9  10    Henry  41.0

# %%
df.loc['Alice':'Charlie',['Age','gender']]    #label,index,include

# %%
df.iloc[0:4]

# %%
df.set_index('name',inplace=True)

# %%
df=df.reset_index()

# %%
df

# %%
df.loc[[1,2,3,7]]

# %%
df.loc[1:5:2]

# fetch row +some columns
df.iloc[1:5,0:1] # all include

# %%
df.loc[1:5,['name','Age']]

# %%
df.loc[[1,3,5,6],['id','name']]

# %%
df.iloc[0:4,0:2]  # exclude  ,index

# %%
df.iloc[:1, :]

# %%
df.iloc[1:, :]

# %%
df.loc[1:4,'name']
# Out:
# 1        Bob
# 2    Charlie
# 3      david
# 4        Eve
# Name: name, dtype: object

# %%
df.loc[[1,2,3,7]]
# Out:
#    id     name   age  gender   salary   join_date department  score  \
# 1   2      Bob  30.0       M  62000.0  2020/03/15         HR   92.0
# 2   3  Charlie   NaN       M  58000.0  15-07-2019         IT   79.0
# 3   4    david  45.0    male      NaN          IT        NaN    NaN
# 7   8      NaN  29.0  FEMALE  51000.0  2021-09-01      Sales   85.0
#
#    is_duplicate_id
# 1            False
# 2            False
# 3            False
# 7            False

# %%
df.loc[1:5:2]
# Out:
#    id   name   age gender   salary   join_date department  score  \
# 1   2    Bob  30.0      M  62000.0  2020/03/15         HR   92.0
# 3   4  david  45.0   male      NaN          IT        NaN    NaN
#
#    is_duplicate_id
# 1            False
# 3            False

# %%
# fetch row +some columns
df.loc[1:5,['id','name']] # all include
# Out:
#    id     name
# 1   2      Bob
# 2   3  Charlie
# 3   4    david
# 4   5      Eve

# %%
df.loc[[1,3,4,6],['id','name']]
# Out:
#    id   name
# 1   2    Bob
# 3   4  david
# 4   5    Eve
# 6   7  Frank

# %%
df.iloc[0:4,0:5]  # exclude
# Out:
#    id     name   age gender   salary
# 0   1    Alice  25.0      F  50000.0
# 1   2      Bob  30.0      M  62000.0
# 2   3  Charlie   NaN      M  58000.0
# 3   4    david  45.0   male      NaN

# %% [markdown]
# # Fixing data types

# %%
#Check current data types
df.dtypes
# Out:
# id              int64
# name           object
# age           float64
# gender         object
# salary        float64
# join_date      object
# department     object
# score         float64
# dtype: object

# %%
df
# Out:
#    id      name    age   gender     salary   join_date department  score
# 0   1     Alice   25.0        F    50000.0  2021-05-10      Sales   88.0
# 1   2       Bob   30.0        M    62000.0  2020/03/15         HR   92.0
# 2   3   Charlie    NaN        M    58000.0  15-07-2019         IT   79.0
# 3   4     david   45.0     male        NaN        None         IT    NaN
# 4   5       Eve   -3.0        F    72000.0  2022-13-01       None   65.0
# 5   5       Eve  200.0     None  1000000.0  2018-11-20    Finance  300.0
# 6   7     Frank   33.0        M    54000.0  wrong_date    finance   73.0
# 7   8      None   29.0   FEMALE    51000.0  2021-09-01      Sales   85.0
# 8   9    Grace     NaN        F    49000.0  2020/12/01      SALES   90.0
# 9  10     Henry   41.0  Unknown        NaN  2017-05-05         IT   82.0

# %%
#join_date is object (string), but it should be datetime.
#age, salary, score may be float even though they could be int.

# %%
age -> float ->Int64 (why not int64 because of nan )
salary ->float64->to_numeric

# %%
Normal NumPy integer dtypes (int64, int32, etc.) cannot store NaN, because NaN is a float-only concept.
So if your column has any missing values, pandas will force it to become float64:
[10, 20, NaN] → dtype becomes float64

# %%
#Convert columns to numeric types
#Convert column to integer, handling NaNs:
df["age"] = df["age"].astype("Int64")  # Pandas nullable integer
df["score"] = df["score"].astype("Int64")

# %%
int64 not handle none 
Int64 can handle none and convert into NAN
object can be convert into string (none converted into <na>)

# %%
df
# Out:
#    id     name   age   gender     salary   join_date department  score
# 0   1    Alice    25        F    50000.0  2021-05-10      Sales     88
# 1   2      Bob    30        M    62000.0  2020/03/15         HR     92
# 2   3  Charlie  <NA>        M    58000.0  15-07-2019         IT     79
# 3   4    david    45     male        NaN          IT        NaN   <NA>
# 4   5      Eve    -3        F    72000.0  2022-13-01        NaN     65
# 5   5      Eve   200      NaN  1000000.0  2018-11-20    Finance    300
# 6   7    Frank    33        M    54000.0  wrong_date    finance     73
# 7   8      NaN    29   FEMALE    51000.0  2021-09-01      Sales     85
# 8   9   Grace   <NA>        F    49000.0  2020/12/01      SALES     90
# 9  10    Henry    41  Unknown        NaN  2017-05-05         IT     82

# %%
df.dtypes
# Out:
# id              int64
# name           object
# age             Int64
# gender         object
# salary        float64
# join_date      object
# department     object
# score           Int64
# dtype: object

# %%
The column contains integers + maybe some NaNs use  Int64
#when  you need to convert a messy column into numbers. use to_numeric with error='coerce'

# %%
#Convert text columns to categorical
#For columns with limited categories like gender or department:

df["gender"] = df["gender"].astype("category")
df["department"] = df["department"].astype("category")

#Benefits:
Reduces memory usage
Faster groupby / filtering

# %% [markdown]
# # Convert date columns

# %%
default MM-DD-YYYY.
Pandas will interpret dates in DD-MM-YYYY when use dayfirst=True

# %%
df["join_date"] = pd.to_datetime(df["join_date"], errors="coerce", format="mixed", dayfirst=True)

#errors="coerce" → invalid dates become NaT (null datetime)
#dayfirst=True → interprets 15-07-2019 as 15th July

# %% [markdown]
# # ADVANCED PANDAS

# %% [markdown]
# # filter the data based on condition

# %%
df["department"].isin(["Sales", "IT"])

# %%
df[df["department"].isin(["Sales", "IT"])]

# %%
df["salary"].isna()

# %%
#Find rows with missing values using isna()
df[df["salary"].isna()]

# %%
#Find all rows where department is Sales (case-insensitive)
df["department"].str.lower().isin(["sales"])

# %%
df[df["department"].str.lower().isin(["sales"])]

# %%
df[df["salary"] > 60000]
# Out:
#    id name   age gender   salary   join_date department  score  \
# 1   2  Bob  30.0      M  62000.0  2020/03/15         HR   92.0
# 4   5  Eve  -3.0      F  72000.0  2022-13-01        NaN   65.0
#
#    is_duplicate_id
# 1            False
# 4            False

# %%
df[df["age"] >= 30]
# Out:
#    id   name   age   gender   salary   join_date department  score  \
# 1   2    Bob  30.0        M  62000.0  2020/03/15         HR   92.0
# 3   4  david  45.0     male      NaN          IT        NaN    NaN
# 6   7  Frank  33.0        M  54000.0  wrong_date    finance   73.0
# 9  10  Henry  41.0  Unknown      NaN  2017-05-05         IT   82.0
#
#    is_duplicate_id
# 1            False
# 3            False
# 6            False
# 9            False

# %%
#Filter invalid ages (negative or > 120)
df[(df["age"] < 0) | (df["age"] > 120)]
# Out:
#    id name  age gender   salary   join_date department  score  is_duplicate_id
# 4   5  Eve -3.0      F  72000.0  2022-13-01        NaN   65.0            False

# %%
Filter missing values in any column
df[df["gender"].isna()]

# %%
Filter department = "Sales" (case-insensitive)
df[df["department"].str.lower() == "sales"]

# %%
Filter rows where gender is M or F only
df[df["gender"].str.upper().isin(["M","F"])]

# %% [markdown]
# # cleaning the categorical column

# %%
df['col1'].str.strip()
df['col1'].str.replace('region','newvalue')
df[['new1','new2']]=df['name'].str.split(',',expand=True)
df['c1']=df['c1'].str.split(',').get(2)
df['c1']=df['c1'].apply(lambda x:x.split()[2])
df['c1']=df['c1'].apply(lambda x:x.split(',')[0])
df['c1']=df['c1'].apply(lambda x:x.split(',',n=1)[0]) # it will split only at first","
df['new']=df[['firstname','lastname']].apply(lambda x:','.join(x),axis=1) # apply on row one row at a time to the lambda:
df['new']=df[['firstname','lastname']].apply(lambda x:','.join(str(value) for value in x,axis=1)

# %% [markdown]
# # performance optimization

# %%
# avoiding python loop for calculation
using:
.apply()
.map()
.applymap()

# %%
# -apply() → Works on Series or DataFrame-----------> for column wise operation
#On Series → apply a function to each value
df['salary_after_tax'] = df['salary'].apply(lambda x: x **2)
                          
                          or 

def sq(x):
    return x**2
df['sq']=df['c1'].apply(sq)

# %%
# On DataFrame → apply row-wise or column-wise
#Row-wise (axis=1)
df['fullname'] = df.apply(lambda x: x['first'] + ' ' + x['last'], axis=1)

#Column-wise (axis=0)
#find max in each column
df.apply(lambda col: col.max())
eg:

# %%
df = pd.DataFrame({
    'math': [90, 70, 50],
    'science': [85, 60, 40],
    'name': ['A', 'B', 'C']
})
df.apply(lambda col: col.max())
# Out:
# math       90
# science    85
# name        C
# dtype: object

# %%
#map() → Works on a Series (one column)
#Used for value-by-value transformation on one column only.
df['gender'] = df['gender'].map({'M': 'Male', 'F': 'Female'})

# %%
#applymap() → Works on entire DataFrame (element-wise)
#Apply function to every cell of the DataFrame.

df = df.applymap(lambda x: str(x).upper())  #Every value in every column is transformed to uppercase.

# %% [markdown]
# # MULTIPLE CONDITIONS

# %%
#Salary > 50000 AND score > 80
df[(df["salary"] > 50000) & (df["score"] > 80)]

# %%
#age between 20 and 40
df[df["age"].between(20, 40)]

# %%
#department is IT or Finance (case-insensitive)
df[df["department"].str.lower().isin(["it", "finance"])]

# %% [markdown]
# # using np.where for filtering

# %%
import pandas as pd
import numpy as np

data = {
    "name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "gender": ["F", "M", "M", "M", "F"],
    "salary": [50000, 60000, 55000, 70000, 65000]
}

df = pd.DataFrame(data)
df
# Out:
#       name gender  salary
# 0    Alice      F   50000
# 1      Bob      M   60000
# 2  Charlie      M   55000
# 3    David      M   70000
# 4      Eve      F   65000

# %% [markdown]
# # created new column based on condition

# %%
df['new']=[1500 if x == 'high' else 800 for x in df['c1']]

# %% [markdown]
# # update the value in existing column

# %%
#If you want to set "tall" in column category where c1 >= 3:
df.loc[df['c1']>=3,'category']='tall'

# %%
#Update category = 'tall' when:
c1 >= 3
gender == 'M'

df.loc[(df['c1'] >= 3) & (df['gender'] == 'M'), 'category'] = 'tall'
df.loc[(df['c1'] >= 3) | (df['salary'] > 50000), 'category'] = 'tall'

# %% [markdown]
# # If you want to create a new column new

# %%
df.loc[df['c1'] >= 3, 'new'] = 'tall'

# %%
#If you want both tall/not tall (optional)
df['new'] = np.where(df['c1'] >= 3, 'tall', 'short')

# %%
np.where(condition,true,false)

# %%
#Add a new column: High salary or Low salary
df["salary_tag"] = np.where(df["salary"] > 60000, "High", "Low")

# %%
#Convert gender into numbers
df["gender_num"] = np.where(df["gender"] == "M", 1, 0)

# %%
df["bonus"] = np.where(df["gender"] == "F", df["salary"] * 0.10, df["salary"] * 0.05)

# %%
#If salary > 60000 and gender = Male → “Top Performer”

df["performance"] = np.where(
    (df["salary"] > 60000) & (df["gender"] == "M"),
    "Top Performer",
    "Normal"
)

# %%
df
# Out:
#       name gender  salary salary_tag  gender_num   bonus    performance
# 0    Alice      F   50000        Low           0  5000.0         Normal
# 1      Bob      M   60000        Low           1  3000.0         Normal
# 2  Charlie      M   55000        Low           1  2750.0         Normal
# 3    David      M   70000       High           1  3500.0  Top Performer
# 4      Eve      F   65000       High           0  6500.0         Normal

# %%
df["category"] = np.where(
    (df["salary"] < 55000) | (df["gender"] == "F"),
    "Special",
    "Regular"
)

# %%
df
# Out:
#       name gender  salary salary_tag  gender_num   bonus    performance  \
# 0    Alice      F   50000        Low           0  5000.0         Normal
# 1      Bob      M   60000        Low           1  3000.0         Normal
# 2  Charlie      M   55000        Low           1  2750.0         Normal
# 3    David      M   70000       High           1  3500.0  Top Performer
# 4      Eve      F   65000       High           0  6500.0         Normal
#
#   category
# 0  Special
# 1  Regular
# 2  Regular
# 3  Regular
# 4  Special

# %% [markdown]
# # Nested np.where() (Multiple Outputs)

# %%
df["rating"] = np.where(
    df["salary"] > 65000, "Excellent",
    np.where(df["salary"] >= 55000, "Good", "Average")
)

# %%
df
# Out:
#       name gender  salary salary_tag  gender_num   bonus    performance  \
# 0    Alice      F   50000        Low           0  5000.0         Normal
# 1      Bob      M   60000        Low           1  3000.0         Normal
# 2  Charlie      M   55000        Low           1  2750.0         Normal
# 3    David      M   70000       High           1  3500.0  Top Performer
# 4      Eve      F   65000       High           0  6500.0         Normal
#
#   category     rating
# 0  Special    Average
# 1  Regular       Good
# 2  Regular       Good
# 3  Regular  Excellent
# 4  Special       Good

# %%
df["status"] = np.where(
    (df["gender"] == "F") & (df["salary"] > 60000), "Female Star",
    np.where(
        (df["gender"] == "M") | (df["salary"] < 55000), "Check",
        "OK"
    )
)

# %%
df
# Out:
#       name gender  salary salary_tag  gender_num   bonus    performance  \
# 0    Alice      F   50000        Low           0  5000.0         Normal
# 1      Bob      M   60000        Low           1  3000.0         Normal
# 2  Charlie      M   55000        Low           1  2750.0         Normal
# 3    David      M   70000       High           1  3500.0  Top Performer
# 4      Eve      F   65000       High           0  6500.0         Normal
#
#   category     rating       status
# 0  Special    Average        Check
# 1  Regular       Good        Check
# 2  Regular       Good        Check
# 3  Regular  Excellent        Check
# 4  Special       Good  Female Star

# %% [markdown]
# # Select columns by data type

# %%
df.select_dtypes(include="number")     # All numeric columns
df.select_dtypes(include="object")     # All object (string) columns
df.select_dtypes(include="category")   # All categorical columns

# %%
numeric_cols = df.select_dtypes(include="number").columns
df[numeric_cols] # boolean masking
#include="number" means all numeric columns: int64, float64, Int64, etc.
# Out:
#    id   age     salary  score
# 0   1    25    50000.0     88
# 1   2    30    62000.0     92
# 2   3  <NA>    58000.0     79
# 3   4    45        NaN   <NA>
# 4   5    -3    72000.0     65
# 5   5   200  1000000.0    300
# 6   7    33    54000.0     73
# 7   8    29    51000.0     85
# 8   9  <NA>    49000.0     90
# 9  10    41        NaN     82

# %%
Merging and Concatenating DataFrames

# %%
left: This will select the entries only in the first DataFrame.
right: This will consider the entries only in the second DataFrame.
outer: This considers the union of all the entries in the DataFrames.
inner: This will result in the intersection of the keys from both DataFrames.

# %%
dataframe_1.merge(dataframe_2, on = ['column_1', 'column_2'], how = 'merge_type')

# %%
Concatenating DataFrames: Add columns or rows from one DataFrame to another

# %%
pd.concat([dataframe_1, dataframe_2], axis = _)
#axis = 0 to append rows
#axis = 1 to append columns

# %%
/marks_1.csv', header = None, sep = '|'
